# %%
############# ------- Funciones simulaciones datos -------------- ########
### --- Simula el id usuario ---- ### 
from shapely import geometry, ops
import numpy as np
import shapely.geometry as shg
from shapely.geometry.polygon import Polygon
from shapely.geometry import Point
import random
import pandas as pd
import geopandas as gpd
import folium
import json
import geojson

# %% [markdown]
# # Cargar los datos del polígonos de Bogotá

# %%
Bogota = pd.read_pickle('Bogota.gzip',compression='gzip')

# %%
#### ----- Extraemos la información ----- ### 
Figura_bogota = Bogota['Poligono'].iloc[0]

# %%
Centroide = Figura_bogota.centroid

# %%
Cordenadas = Centroide.coords[0]
print(Cordenadas)
# Out:
# (-74.18107270162268, 4.316107698094774)

# %%
Latitud = Cordenadas[1]
Longitud = Cordenadas[0]

# %% [markdown]
# ## Mapa

# %%
Mapa = folium.Map(location=[Latitud,Longitud],zoom_start=10,tiles='cartodbpositron')

# %%
Mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#### ------ Crear geojson ----- ###### 
geojson_bogota = geojson.Feature(geometry=Figura_bogota)
### ----- Organizar la estructura ---- ###
geo_str = json.dumps(geojson_bogota) 
####### ------- Cargarlo ----- #######
geo_str = json.loads(geo_str)

# %% [markdown]
# ## Figura

# %%
folium.GeoJson(geo_str,
style_function=lambda feature: {
    'fillColor': 'gray',
    'color': '#7d868c',
    'weight': 1,
    'fillOpacity':0.2,
},
highlight_function=lambda x: {'weight':10,'fillColor':'#fec821','color': '#fec821'},tooltip='Bogota',
name='Mexico Population').add_to(Mapa)

# %%
Mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Generar puntos aleatorios

# %%
def generate_random(number, poligono):
    list_of_points = []
    minx, miny, maxx, maxy = poligono.bounds
    counter = 0
    while counter < number:
        pnt = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if poligono.contains(pnt):
            list_of_points.append(pnt)
            counter += 1
    return list_of_points

# %%
##### Generar 10 puntos aleatorios ----- #######
Puntos_aleatorios = generate_random(number = 10,poligono=Figura_bogota)

# %%
Puntos_aleatorios
# Out:
# [<shapely.geometry.point.Point at 0x106039690>,
#  <shapely.geometry.point.Point at 0x11b7ce550>,
#  <shapely.geometry.point.Point at 0x106039e50>,
#  <shapely.geometry.point.Point at 0x11bf9df10>,
#  <shapely.geometry.point.Point at 0x11bfacb90>,
#  <shapely.geometry.point.Point at 0x11bfacc50>,
#  <shapely.geometry.point.Point at 0x11bfac2d0>,
#  <shapely.geometry.point.Point at 0x11bfac450>,
#  <shapely.geometry.point.Point at 0x11bfac490>,
#  <shapely.geometry.point.Point at 0x11bf9db50>]

# %%
###### -------- Extraer cordenadas ------- ##### 
Coordenadas_aleatorias = list(map(lambda x: x.coords[0],Puntos_aleatorios))

# %%
Coordenadas_aleatorias
# Out:
# [(-74.31442333653679, 3.992863338978628),
#  (-74.00733223163266, 4.565959745654473),
#  (-74.16399704238528, 4.5465022221359614),
#  (-74.14802409522288, 4.312017950777489),
#  (-74.21383364694888, 4.355627582196108),
#  (-74.20253114113918, 4.3712213752103795),
#  (-74.01055965511969, 4.607177356796153),
#  (-74.19285493908022, 4.0599585265749365),
#  (-74.13137329878953, 4.164867656290789),
#  (-74.12627899394457, 4.547379358196091)]

# %%
Coordenadas_aleatorias = pd.DataFrame(Coordenadas_aleatorias)
Coordenadas_aleatorias.columns = ['Longitud','Latitud']

# %%
Coordenadas_aleatorias
# Out:
#     Longitud   Latitud
# 0 -74.314423  3.992863
# 1 -74.007332  4.565960
# 2 -74.163997  4.546502
# 3 -74.148024  4.312018
# 4 -74.213834  4.355628
# 5 -74.202531  4.371221
# 6 -74.010560  4.607177
# 7 -74.192855  4.059959
# 8 -74.131373  4.164868
# 9 -74.126279  4.547379

# %%
###### --- Graficar puntos en el mapa ------ ###### 
for j in range(0,len(Coordenadas_aleatorias)):
    folium.Marker([Coordenadas_aleatorias['Latitud'].iloc[j],Coordenadas_aleatorias['Longitud'].iloc[j]]).add_to(Mapa)

# %%
Mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
