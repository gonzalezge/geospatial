# %% [markdown]
# <img src="https://raw.githubusercontent.com/paular143/images_notebooks/master/logo-sin-nombre.png" alt="Universidad de Los Andes" style="width: 90px;" align="left" frameborder="300"/>
#
# **UNIVERSIDAD DE LOS ANDES** <br>
# **FACULTAD DE ECONOMÍA - EDUCACIÓN CONTINUADA** <br>
# **Análisis espacial de datos y sus aplicaciones en Python 2020** <br>
# **PROFESORES:** Germán González y Mateo Dulce <br><br>
#
#
# # Clase 5: Rutas
#
# - Carreteras

# %%
# !pip3 install shapely
# !pip3 install pyproj
# !pip3 install folium
# !pip3 install pandas
# !pip3 install requests
# !pip3 install geopy
# !pip3 install geojson
# !pip3 install xlrd
# !pip3 install rtree
# !pip3 install networkx
# !pip3 install osmnx

import pandas as pd
import urllib, json
import geopandas as gpd
import osmnx as ox
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import rtree
import folium
import geojson
from shapely.geometry import LineString, Point
import datetime
from functools import partial
import pyproj
from shapely.ops import transform

# %% [markdown]
# ### Carreteras - OXMN

# %% [markdown]
# ## Dirección Lugar

# %%
Informacion_carretera = ox.graph_from_address('Usaquen,Bogotá,Colombia', network_type='drive',dist=2000)

# %% [markdown]
# ## Gráfico

# %%
figura, ax = ox.plot_graph(Informacion_carretera)

# %%
figura.savefig('usaquen.png')

# %% [markdown]
# ## Por nombre

# %%
Informacion_carretera = ox.graph_from_place('Melbourne,Victoria,Australia', network_type='drive')
figura, ax = ox.plot_graph(Informacion_carretera)

# %% [markdown]
# ## Con polígonos

# %%
Localidades = pd.read_pickle('Localidades.gzip',compression='gzip')

# %%
#### ------ Filtramos Usaquen ------ ######
Usaquen = Localidades[Localidades['Localidad'] == 'Usaquen']
Poligono_usaquen = Usaquen['geometry'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-9e5e294d319a> in <module>
#       1 #### ------ Filtramos Usaquen ------ ######
# ----> 2 Usaquen = Localidades[Localidades['Localidad'] == 'Usaquen']
#       3 Poligono_usaquen = Usaquen['geometry'].iloc[0]
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/geopandas/geodataframe.py in __getitem__(self, key)
#     804         GeoDataFrame.
#     805         """
# --> 806         result = super(GeoDataFrame, self).__getitem__(key)
#     807         geo_col = self._geometry_column_name
#     808         if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
# -> 2845         return self._take_with_is_copy(indexer, axis=0)
#    2846
#    2847     def _getitem_multilevel(self, key):
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3393
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#    3397         return self._constructor(new_data).__finalize__(self)
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1392         new_labels = self.axes[axis].take(indexer)
#    1393         return self.reindex_indexer(
# -> 1394             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1395         )
#    1396
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1842         # but are passed the axis depending on the calling routing
#    1843         # if its REALLY axis 0, then this will be a reindex and not a take
# -> 1844         new_values = self.values.take(indexer, fill_value=fill_value, allow_fill=True)
#    1845
#    1846         # Called from three places in managers, all of which satisfy
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/geopandas/array.py in take(self, indices, allow_fill, fill_value)
#     721         if allow_fill and fill_value is None:
#     722             result[pd.isna(result)] = None
# --> 723         return GeometryArray(result, crs=self.crs)
#     724
#     725     def _fill(self, idx, value):
#
# ~/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/geopandas/array.py in crs(self)
#     293         such as an authority string (eg "EPSG:4326") or a WKT string.
#     294         """
# --> 295         return self._crs
#     296
#     297     @crs.setter
#
# AttributeError: 'GeometryArray' object has no attribute '_crs'

# %%
Informacion_carretera = ox.graph_from_polygon(Poligono_usaquen, network_type='drive')
figura, ax = ox.plot_graph(Informacion_carretera)

# %% [markdown]
# ## Geo Pandas

# %%
Nodos_usaquen, Carreteras_usaquen = ox.graph_to_gdfs(Informacion_carretera, nodes=True, edges=True)
Carreteras_usaquen.to_crs(epsg=4326, inplace=True)

# %% [markdown]
# ## Carreteras

# %%
Nodos_usaquen
# Out:
#                    y          x       osmid          highway  \
# 7567228937  4.752582 -74.023442  7567228937              NaN
# 532553749   4.762977 -74.031195   532553749              NaN
# 6489505814  4.758328 -74.029474  6489505814              NaN
# 482795551   4.691946 -74.049055   482795551              NaN
# 368394272   4.720323 -74.038780   368394272              NaN
# ...              ...        ...         ...              ...
# 312410089   4.749405 -74.044027   312410089              NaN
# 312410090   4.749211 -74.043187   312410090              NaN
# 310665201   4.714582 -74.037935   310665201  traffic_signals
# 7567155189  4.748760 -74.037614  7567155189              NaN
# 7567155198  4.741935 -74.036761  7567155198              NaN
#
#                              geometry
# 7567228937  POINT (-74.02344 4.75258)
# 532553749   POINT (-74.03119 4.76298)
# 6489505814  POINT (-74.02947 4.75833)
# 482795551   POINT (-74.04905 4.69195)
# 368394272   POINT (-74.03878 4.72032)
# ...                               ...
# 312410089   POINT (-74.04403 4.74941)
# 312410090   POINT (-74.04319 4.74921)
# 310665201   POINT (-74.03794 4.71458)
# 7567155189  POINT (-74.03761 4.74876)
# 7567155198  POINT (-74.03676 4.74193)
#
# [3956 rows x 5 columns]

# %% [markdown]
# ## Nodos

# %%
Nodos_usaquen.head()
# Out:
#                    y          x       osmid highway                   geometry
# 7567228937  4.752582 -74.023442  7567228937     NaN  POINT (-74.02344 4.75258)
# 532553749   4.762977 -74.031195   532553749     NaN  POINT (-74.03119 4.76298)
# 6489505814  4.758328 -74.029474  6489505814     NaN  POINT (-74.02947 4.75833)
# 482795551   4.691946 -74.049055   482795551     NaN  POINT (-74.04905 4.69195)
# 368394272   4.720323 -74.038780   368394272     NaN  POINT (-74.03878 4.72032)

# %%
### Proyectar el grafico de nodos a otro sistema 
Grafico_projectado = ox.project_graph(Informacion_carretera,to_crs={'init': 'epsg:4326'})
fig, ax = ox.plot_graph(Grafico_projectado)
plt.tight_layout()
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
Estadisticas = ox.basic_stats(Grafico_projectado)
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/pyproj/crs/crs.py:280: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(projparams)

# %%
Estadisticas
# Out:
# {'n': 3956,
#  'm': 9192,
#  'k_avg': 4.6471183013144595,
#  'intersection_count': 3274,
#  'streets_per_node_avg': 2.827603640040445,
#  'streets_per_node_counts': {0: 0, 1: 682, 2: 3, 3: 2603, 4: 654, 5: 11, 6: 3},
#  'streets_per_node_proportion': {0: 0.0,
#   1: 0.1723963599595551,
#   2: 0.0007583417593528817,
#   3: 0.6579878665318504,
#   4: 0.1653185035389282,
#   5: 0.002780586450960566,
#   6: 0.0007583417593528817},
#  'edge_length_total': 883680.9179999972,
#  'edge_length_avg': 96.13587010443834,
#  'street_length_total': 543334.2959999999,
#  'street_length_avg': 97.51153912419237,
#  'street_segments_count': 5572,
#  'node_density_km': None,
#  'intersection_density_km': None,
#  'edge_density_km': None,
#  'street_density_km': None,
#  'circuity_avg': 1.074807678265068,
#  'self_loop_proportion': 0.0008703220191470844,
#  'clean_intersection_count': None,
#  'clean_intersection_density_km': None}

# %% [markdown]
#  Para poder extraer las estadísticas más avanzadas (y algunas de las que faltan más arriba) de la red de calles, se requiere tener información sobre el área de cobertura de la red. Calculemos el área del casco convexo de la red de calles y veamos qué podemos obtener. Como ciertas estadísticas se producen por separado para cada nodo, producen una gran cantidad de resultados.

# %%
#### -------- Figura convexa ------ ########
area = Carreteras_usaquen.unary_union.convex_hull.area

# %%
area
# Out:
# 0.0041308569681800435

# %%
stats = ox.basic_stats(Grafico_projectado, area=area)

# %%
stats
# Out:
# {'n': 3956,
#  'm': 9192,
#  'k_avg': 4.6471183013144595,
#  'intersection_count': 3274,
#  'streets_per_node_avg': 2.827603640040445,
#  'streets_per_node_counts': {0: 0, 1: 682, 2: 3, 3: 2603, 4: 654, 5: 11, 6: 3},
#  'streets_per_node_proportion': {0: 0.0,
#   1: 0.1723963599595551,
#   2: 0.0007583417593528817,
#   3: 0.6579878665318504,
#   4: 0.1653185035389282,
#   5: 0.002780586450960566,
#   6: 0.0007583417593528817},
#  'edge_length_total': 883680.9179999972,
#  'edge_length_avg': 96.13587010443834,
#  'street_length_total': 543334.2959999999,
#  'street_length_avg': 97.51153912419237,
#  'street_segments_count': 5572,
#  'node_density_km': 957670534340.2192,
#  'intersection_density_km': 792571620179.4434,
#  'edge_density_km': 213921935522576.53,
#  'street_density_km': 131530648527726.67,
#  'circuity_avg': 1.074807678265068,
#  'self_loop_proportion': 0.0008703220191470844,
#  'clean_intersection_count': None,
#  'clean_intersection_density_km': None}

# %% [markdown]
# Ahora calculemos el camino más corto entre dos puntos. Primero necesitamos especificar las ubicaciones de origen y destino para nuestra ruta. Usemos el centroide de nuestra red como la ubicación de origen y el punto más alejado de Oriente en nuestra red como la ubicación de destino.
#
# Primero determinemos el centroide de nuestra red. Podemos aprovechar el atributo de límites para descubrir los cuadros delimitadores para cada característica en nuestros datos. Luego hacemos una unión unaria de esas características y hacemos una geometría de cuadro delimitador de esos valores que nos permite determinar el centroide de nuestros datos.

# %%
Origen = (4.696971,-74.030345) 
Destino = (4.686538,-74.030345)

# %%
######## --------------- Nodos cercanos ---------- ########## 
Pos_cercano_origen = ox.get_nearest_node(Grafico_projectado, Origen, method='euclidean')
Nodo_cercano_origen = Nodos_usaquen.loc[Pos_cercano_origen]

###### ----------- Vecino cercano -------- #########
Pos_destino_origen = ox.get_nearest_node(Grafico_projectado, Destino, method='euclidean')
Nodo_destino_origen = Nodos_usaquen.loc[Pos_destino_origen]

# %% [markdown]
# ## Se consolida un Geodataframe con los puntos de análisis

# %%
Nodos_interes = gpd.GeoDataFrame([Nodo_cercano_origen, Nodo_destino_origen], geometry='geometry', crs=Nodos_usaquen.crs)

# %%
Nodos_interes
# Out:
#                   y          x      osmid  highway                   geometry
# 268627784  4.697099 -74.030349  268627784      NaN  POINT (-74.03035 4.69710)
# 519033787  4.686574 -74.030203  519033787      NaN  POINT (-74.03020 4.68657)

# %%
Pos_destino_origen
# Out:
# 519033787

# %%
Ruta_corta = nx.shortest_path(G=Grafico_projectado, source=Pos_cercano_origen, target=Pos_destino_origen, weight='length',method='dijkstra')

# %%
Ruta_corta
# Out:
# [268627784,
#  262391190,
#  268629564,
#  483413842,
#  268627729,
#  268627731,
#  268627732,
#  268627808,
#  268628369,
#  268628322,
#  475150468,
#  476344216,
#  2010133051,
#  3545999051,
#  3545996887,
#  826233761,
#  5686482230,
#  254347540,
#  5935325521,
#  834679228,
#  476509087,
#  476509146,
#  476509091,
#  476509092,
#  519033824,
#  519033784,
#  519033787]

# %%
ox.__version__
# Out:
# '0.14.1'

# %%
fig, ax = ox.plot_graph_route(Grafico_projectado, Ruta_corta, origin_point=Origen, destination_point=Destino)

plt.tight_layout()
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/clase/lib/python3.7/site-packages/osmnx/plot.py:55: UserWarning: The origin_point, destination_point parameter(s) have been deprecated and will be removed in the next release.
#   warnings.warn(msg)

# %% [markdown]
# ### Estructura de la ruta

# %%
Puntos_ruta = Nodos_usaquen.loc[Ruta_corta]

# %%
Ruta = LineString(list(Puntos_ruta.geometry.values))

# %% [markdown]
# ## Distancia ruta

# %%
####### -------- Convertir a un sistema en donde la unidad es metros ------- #######
A_metros = partial(
    pyproj.transform,
    pyproj.Proj('EPSG:4326'),
    pyproj.Proj('EPSG:3857'))

# %%
### ----- Pasar los puntos originales a lat,lon ---- #######
Puntos_originales = Puntos_ruta['geometry'].apply(lambda x: Point(x.coords[0][1],x.coords[0][0]))
Puntos_metros = list(map(lambda x: transform(A_metros, x),list(Puntos_originales) ))

# %%
Puntos_metros[0].coords[0]
# Out:
# (-8241020.698268584, 523465.2948287053)

# %%
Ruta_metros = LineString(Puntos_metros)

# %%
Ruta_metros

# %%
Ruta_metros.length
# Out:
# 2264.06590136388

# %% [markdown]
# # HERE

# %% [markdown]
# ## Mapa

# %%
mapa = folium.Map(location=[Origen[0],Origen[1]],zoom_start=15,tiles='cartodbpositron')

### ---------- Punto inicial --------- #####
folium.Marker([Origen[0],Origen[1]],icon=folium.Icon(color='red'),popup='Inicio').add_to(mapa)
### ---------- Punto final --------- #####
folium.Marker([Destino[0],Destino[1]],icon=folium.Icon(color='green'),popup='Final').add_to(mapa)

###### ---------- Ruta ----------- ########

Ruta_geojson = json.loads(json.dumps(geojson.Feature(geometry=Ruta)) )
folium.GeoJson(Ruta_geojson,
style_function=lambda feature: {
    'fillColor': '#415464',
    'color': '#415464',
    'weight': 2,'dashArray': '5, 5',
    'fillOpacity':0.2,
},highlight_function=lambda x: {'weight':10,'fillColor':'#fec821','color': '#fec821'},tooltip='Ruta',
name='Ruta').add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Parametros

# %%
Inicio
# Out:
# '4.696971,-74.030345'

# %%
API_key = '5ELMuTthvjz1Blo6MzU2yhUqD7Jig9tBX4bDrz247-Y'
#### ------- Latitude, longitude ----- ###### 
Inicio = str(Origen[0])+','+str(Origen[1])
Final = str(Destino[0])+','+str(Destino[1])
##### ----------- Modo -------- ########
# ---- car, pedestrian	, publicTransport, truck, bicycle
Modo = 'pedestrian'
# --- Walking speed --- ### 
Velocidad_caminar = 1.4
Velocidad_caminar = '&walkSpeed=' + str(Velocidad_caminar)

### ------ Analisis tiempo ---- #### 
Tiempo = '2020-07-01 '
Tiempo = datetime.datetime.strptime('2020-06-12 14:00:00','%Y-%m-%d %H:%M:%S')
Tiempo=Tiempo.strftime('%Y-%m-%dT%H:%M:%S')
Tiempo = '&departure='+str(Tiempo)

##### -------- Tipo de ruta ----- ####### 
## Fastest: Más rapida 
## shortest: Más Corta 
## balanced: Balanceada
Tipo_ruta = 'fastest'

# %% [markdown]
# ## Solicitud

# %%
####### ------- Solicitud -------- #####
built_url = 'https://route.ls.hereapi.com/routing/7.2/calculateroute.json?apikey='+API_key+'&waypoint0=geo!'+Inicio+'&waypoint1=geo!'+Final+'&mode='+Tipo_ruta+';'+Modo+';traffic:enabled&legattributes=li&c&returnelevation=true&metricSystem=imperial' + str(Velocidad_caminar) +  str(Tiempo)
html_data = pd.read_json(built_url)
Datos_ruta = pd.DataFrame(pd.DataFrame(pd.DataFrame(html_data.T['route'].iloc[0])['leg'].iloc[0])['link'].iloc[0])
Datos_ruta = pd.DataFrame(pd.concat([pd.DataFrame(x)[0] for x in Datos_ruta['shape']]))[0].reset_index(drop=True)
Latitudes = pd.DataFrame({'latitude': Datos_ruta.apply(lambda x: float(x.split(',')[0])),'longitude': Datos_ruta.apply(lambda x: float(x.split(',')[1]))})
Ruta_here  = LineString(list(Latitudes.apply(lambda x: (x['longitude'],x['latitude']),axis=1)))

# %% [markdown]
# ## Mapa

# %%
mapa = folium.Map(location=[Origen[0],Origen[1]],zoom_start=15,tiles='cartodbpositron')

### ---------- Punto inicial --------- #####
folium.Marker([Origen[0],Origen[1]],icon=folium.Icon(color='red'),popup='Inicio').add_to(mapa)
### ---------- Punto final --------- #####
folium.Marker([Destino[0],Destino[1]],icon=folium.Icon(color='green'),popup='Final').add_to(mapa)

###### ---------- Ruta ----------- ########

Ruta_geojson = json.loads(json.dumps(geojson.Feature(geometry=Ruta)) )
folium.GeoJson(Ruta_geojson,
style_function=lambda feature: {
    'fillColor': 'red',
    'color': 'red',
    'weight': 2,'dashArray': '5, 5',
    'fillOpacity':0.2,
},highlight_function=lambda x: {'weight':10,'fillColor':'#fec821','color': '#fec821'},tooltip='Ruta',
name='Ruta').add_to(mapa)

Ruta_geojson_here = json.loads(json.dumps(geojson.Feature(geometry=Ruta_here)) )
folium.GeoJson(Ruta_geojson_here,
style_function=lambda feature: {
    'fillColor': 'green',
    'color': 'green',
    'weight': 2,'dashArray': '5, 5',
    'fillOpacity':0.2,
},highlight_function=lambda x: {'weight':10,'fillColor':'#fec821','color': '#fec821'},tooltip='Ruta',
name='Ruta').add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
