# %% [markdown]
# <img src="https://raw.githubusercontent.com/paular143/images_notebooks/master/logo-sin-nombre.png" alt="Universidad de Los Andes" style="width: 90px;" align="left" frameborder="300"/>
#
# **UNIVERSIDAD DE LOS ANDES** <br>
# **FACULTAD DE ECONOMÍA - EDUCACIÓN CONTINUADA** <br>
# **Análisis espacial de datos y sus aplicaciones en Python 2020** <br>
# **PROFESORES:** Germán González y Mateo Dulce <br><br>
#
#
# # Clase 7: Aprendizaje supervisado: análisis de regresión
#
# - Regresión lineal simple y multivariada.
# - Regresión lineal espacial.
# - Aplicación: predicción de precio de metro cuadrado.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/RodrigoLaraMolina/DPATTSrc/master/ML2.png" alt="ML" style="width: 500px;" align="center" frameborder="200"/>
#
# _(Imagen tomada de [Medium - Different types of Machine learning and their types.](https://medium.com/deep-math-machine-learning-ai/different-types-of-machine-learning-and-their-types-34760b9128a2))_

# %% [markdown]
# ## 0. Introducción a Scikit-Learn
#
# Existen varias librerias de Python que proveen implementaciones solidas de multiples algoritmos de aprendizaje de máquinas. Una de las más conocidas es [Scikit-Learn](http://scikit-learn.org). Scikit-Learn se caracteriza por ser una API limpia, uniforme y optimizada, y por tener una documentación en línea muy útil y completa. Una ventaja de esta uniformidad es que una vez que comprende el uso básico y la sintaxis de Scikit-Learn para un tipo de modelo, cambiar a un nuevo modelo o algoritmo es muy sencillo.
#
# ### Uso básico de la API
#
# Por lo general, los pasos a seguir para utilizar los modelos implementados en Scikit-Learn son:
#
# 1. Seleccionar una clase de modelo importando la clase de estimador apropiada de Scikit-Learn.
# 2. Seleccionar los hiper parámetros del modelo al declarar la clase anterior con estos valores.
# 3. Organizar los datos en una matriz de variables y un vector objetivo.
# 4. Ajustar el modelo a los datos llamando al método `` .fit() `` de la instancia del modelo.
# 5. Predecir el modelo en nuevos datos.

# %% [markdown]
# ## 1. Mínimos Cuadrados Ordinarios
# ### Regresión lineal univariada
#
# Los modelos de aprendizaje supervisado buscan predecir o modelar una variable objetivo $y$ en función de ciertas características o atributos $x$ de cada observación
#
# $$ y = f(x) $$
#
# La función $f$ captura la manera en que las variables explicativas $x$ se combinan para obtener el resultado $y$.
#
# Los modelos de regresión lineal son un buen punto de partida para las tareas de regresión. Dichos modelos son populares porque pueden ajustarse muy rápidamente y son muy interpretables.
#
# En el caso del modelo de Regresión Lineal, se supone que las variables se ponderan linealmente para construir $y$.
#
# Un ajuste en línea recta es un modelo de la forma
#
# $$
# y = ax + b
# $$
# donde $a$ es la *pendiente*, y $b$ is el *intercepto*.
#
# Considere los siguientes datos, que están dispersos alrededor de un modelo lineal con una pendiente de 2 y una intersección de -5:

# %%
# importar paquetes estandar
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/motus/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ### Generar datos sintéticos

# %%
# generamos puntos distribuidos de manera uniforme entre 0 y 10
# para tener replicabilidad
rng = np.random.RandomState(1)
x = 10 * rng.rand(50,1)

# %%
x[:,0]
# Out:
# array([4.17022005e+00, 7.20324493e+00, 1.14374817e-03, 3.02332573e+00,
#        1.46755891e+00, 9.23385948e-01, 1.86260211e+00, 3.45560727e+00,
#        3.96767474e+00, 5.38816734e+00, 4.19194514e+00, 6.85219500e+00,
#        2.04452250e+00, 8.78117436e+00, 2.73875932e-01, 6.70467510e+00,
#        4.17304802e+00, 5.58689828e+00, 1.40386939e+00, 1.98101489e+00,
#        8.00744569e+00, 9.68261576e+00, 3.13424178e+00, 6.92322616e+00,
#        8.76389152e+00, 8.94606664e+00, 8.50442114e-01, 3.90547832e-01,
#        1.69830420e+00, 8.78142503e+00, 9.83468338e-01, 4.21107625e+00,
#        9.57889530e+00, 5.33165285e+00, 6.91877114e+00, 3.15515631e+00,
#        6.86500928e+00, 8.34625672e+00, 1.82882773e-01, 7.50144315e+00,
#        9.88861089e+00, 7.48165654e+00, 2.80443992e+00, 7.89279328e+00,
#        1.03226007e+00, 4.47893526e+00, 9.08595503e+00, 2.93614148e+00,
#        2.87775339e+00, 1.30028572e+00])

# %%
rng.randn(50)
# Out:
# array([-0.6871727 , -0.84520564, -0.67124613, -0.0126646 , -1.11731035,
#         0.2344157 ,  1.65980218,  0.74204416, -0.19183555, -0.88762896,
#        -0.74715829,  1.6924546 ,  0.05080775, -0.63699565,  0.19091548,
#         2.10025514,  0.12015895,  0.61720311,  0.30017032, -0.35224985,
#        -1.1425182 , -0.34934272, -0.20889423,  0.58662319,  0.83898341,
#         0.93110208,  0.28558733,  0.88514116, -0.75439794,  1.25286816,
#         0.51292982, -0.29809284,  0.48851815, -0.07557171,  1.13162939,
#         1.51981682,  2.18557541, -1.39649634, -1.44411381, -0.50446586,
#         0.16003707,  0.87616892,  0.31563495, -2.02220122, -0.30620401,
#         0.82797464,  0.23009474,  0.76201118, -0.22232814, -0.20075807])

# %%
# generamos los valores de y usando un modelo lineal con pendiente 2
# e intercepto -5 mas un ruido alatorio
y = 2 * x[:,0] - 5 + rng.randn(50)

# construit un grafico de puntos
plt.scatter(x, y);

# %% [markdown]
# ### Encontrar el mejor ajuste utilizando Scikit-Learn

# %%
#### importar LinearRegression de Scikit-Learn
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept = True)

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print("Pendiente del modelo:    ", model.coef_[0])
print("Intercepto del modelo:", model.intercept_)
# Out:
# Pendiente del modelo:     2.0429481538357774
# Intercepto del modelo: -5.131958850853588

# %%
model.predict(x)
# Out:
# array([ 3.3875845 ,  9.58389709, -5.12962223,  1.04453886, -2.13381209,
#        -3.24552923, -1.3267593 ,  1.92766764,  2.97379494,  5.87578767,
#         3.43196774,  8.86672028, -0.95510539, 12.8075251 , -4.57244452,
#         8.56534477,  3.3933619 ,  6.28178469, -2.26392648, -1.08484814,
#        11.22683753, 14.64912313,  1.27113461,  9.01183324, 12.77221716,
#        13.14439147, -3.3945497 , -4.33408988, -1.66241143, 12.80803721,
#        -3.12278402,  3.4710516 , 14.43722762,  5.7603315 ,  9.00273188,
#         1.31386191,  8.89289918, 11.9190109 , -4.75833883, 10.19310058,
#        15.06996051, 10.15267757,  0.59736651, 10.99260862, -3.02310506,
#         4.01827367, 13.43017621,  0.86642597,  0.74714212, -2.47554254])

# %%
plt.scatter(x,y)
plt.plot(x, model.predict(x), color = 'red');

# %%
model.intercept_ + model.coef_[0]*10
# Out:
# 15.297522687504186

# %% [markdown]
# ## Métricas de desempeño
#
# - $MSE = \text{Mean squared error (error cuadrático medio)} = mean((Y-\hat Y)^2)$
# <br>
# <br>
# - $MAE = \text{Mean absolute error (error absoluto medio)} = mean(\mid Y-\hat Y \mid)$
# <br>
# <br>
# - $R^2 = \dfrac{\sigma^{2}_{XY}}{\sigma^{2}_{X}\sigma^{2}_{Y}}$ donde $\sigma^{2}_{XY}$ es la covarianza de $X,Y$, $\sigma^{2}_{X}$ la varianza de $X$ y $\sigma^{2}_{Y}$ la varianza de $Y$.

# %%
model.predict(np.array(0).reshape(-1,1))
# Out:
# array([-5.13195885])

# %%
# realizar la predicción dentro de muestra
y_pred = model.predict(x)

# %% [markdown]
# #### La idea detrás de cualquier métrica o esquema de validación es comparar la predicción realizada por el modelo (y_pred, arriba) contra los datos reales conocidos de una muestra de datos (y).
#
# La sintaxis de las métricas es, en general: importar la métrica deseada desde [sklearn.metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) y luego llamarla pasando los y_reales y los y_predichos.

# %%
# error cuadrático medio en el entrenamiento
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,y_pred)
print("El modelo de regresión lineal tiene un MSE = {0:.3f} dentro de muestra".format(mse))
# Out:
# El modelo de regresión lineal tiene un MSE = 0.699 dentro de muestra

# %%
# error absoluto promedio en el entrenamiento
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y,y_pred)
print("El modelo de regresión lineal tiene un MAE = {0:.3f} dentro de muestra".format(mae))
# Out:
# El modelo de regresión lineal tiene un MAE = 0.651 dentro de muestra

# %%
# R cuadrado en el entrenamiento
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print("El modelo de regresión lineal tiene un R2 = {0:.3f} dentro de muestra".format(r2))
# Out:
# El modelo de regresión lineal tiene un R2 = 0.982 dentro de muestra

# %% [markdown]
# ## Otras métricas de desempeño
#
# - $RMSE = \text{Root mean squared error (raiz del error cuadrático medio)} = \sqrt{mean((Y-\hat Y)^2)}$
# <br>
# <br>
# - $MAPE = \text{Mean absolute percentage error (error absoluto porcentual medio)} = mean\left(\frac{\mid Y-\hat Y \mid}{Y}\right)$
# <br>
# <br>

# %% [markdown]
# Existen otros paquetes que contienen implementaciones de este mismo modelo. Por ejemplo pueden probar con: <br>
# ``statsmodels.formula.api.ols``

# %% [markdown]
# ### Regresión Lineal Múltiple
#
# El estimador ``LinearRegression`` también puede estimar modelos multivariables de la forma
#
# $$
# y = b_0 + b_1 x_1 + b_2 x_2 + \cdots + b_k x_k
# $$
#
# donde hay multiples valores para $x$.
# Geométricamente, esto es ajustar un plano a puntos en tres dimenciones o un hiper plano para dimensiones mayores.
#
# En términos analíticos, queremos que para unos mismos valores de $(b_0, b_1, b_2, ..., b_k)$, simultaneamente todos nuestros registros logren una buena predicción.
#
# $$ y_1 = b_0 + b_1 x_{11} + b_2 x_{21} + \cdots + b_k x_{k1} $$
# $$ y_2 = b_0 + b_1 x_{12} + b_2 x_{22} + \cdots + b_k x_{k2} $$
# $$ \vdots $$
# $$ y_n = b_0 + b_1 x_{1n} + b_2 x_{2n} + \cdots + b_k x_{kn} $$

# %% [markdown]
# Finalmente, la forma de estimar esto se conoce como Minimos Cuadrados Ordinarios y queremos que el error promedio que comete nuestro modelo sea el menor posible.
#
# Filosóficamente, esto es lo que siempre se quiere en un modelo de aprendizaje de máquinas, y lo que varía es la forma en que se mide este error.
#
# En este caso, queremos encontrar $\hat \beta$ que minimice el error $(Y-\hat Y)^2$ donde $\hat Y = X \hat \beta$. <br>
#
# Esto se consigue con los coeficientes $\hat \beta = (X^TX)^{-1}X^TY$

# %%
# creamos datos con 2 variables distribuidas uniformemente entre 0 y 10
# creamos la variable dependiente y como un modelo lineal de x
rng = np.random.RandomState(1234) # replicabilidad
x = 10 * rng.rand(100, 2)
y = 0.5 + np.dot(x, [1.5, -2.]) + rng.randn(100)

# %%
modelo = LinearRegression(fit_intercept = True)

# %%
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
modelo.intercept_
# Out:
# 0.6707340246733002

# %%
modelo.coef_
# Out:
# array([ 1.49622311, -2.01475073])

# %%
x[:,0]
# Out:
# array([1.9151945 , 4.37727739, 7.79975808, 2.76464255, 9.58139354,
#        3.5781727 , 6.83462935, 3.70250755, 5.03083165, 7.72826622,
#        3.64885984, 0.75381242, 9.33140102, 3.97202578, 3.16836122,
#        8.6912739 , 8.02147642, 7.04260971, 2.18792106, 4.42140755,
#        0.59809223, 0.47355279, 5.9462478 , 0.43324063, 3.29668446,
#        1.11894318, 5.65944643, 6.17441709, 7.90524133, 9.58801762,
#        2.8525096 , 4.78093796, 3.82317452, 4.51648408, 1.239427  ,
#        7.38523056, 4.71632534, 2.29218565, 4.16753538, 0.06208517,
#        4.36893172, 9.18198075, 7.05997565, 7.46063409, 6.33725769,
#        1.52572775, 5.28224278, 4.80359179, 5.36878193, 0.57115638,
#        7.67116628, 7.96867184, 9.65836532, 0.29647001, 1.14065699,
#        3.25707414, 4.57811649, 8.79069162, 3.48008793, 9.01796051,
#        7.26658462, 7.79163801, 2.91125245, 3.35174659, 0.73342544,
#        3.23194814, 8.53898567, 1.73067227, 9.94653829, 3.17546823,
#        0.09348575, 9.77241431, 0.84773843, 7.28428676, 5.52468939,
#        9.74495138, 2.55653286, 7.76180723, 7.61603914, 6.58622782,
#        2.01755692, 9.5219541 , 9.93567363, 5.45122166, 8.90557188,
#        5.9341133 , 3.23094693, 2.15634063, 3.65619087, 7.82735592,
#        6.22776587, 8.405377  , 4.43908981, 3.6323976 , 4.75566573,
#        6.40880435, 1.71465261, 1.27029394, 6.04334005, 8.02374182])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(211,projection='3d')

ax.scatter(x.T[0],x.T[1], c='r', marker='o', s=5)

# generar una grilla de x,y
xx, yy = np.meshgrid(x.T[0],x.T[1])

exog = pd.core.frame.DataFrame({'X': xx.ravel(), 'Y': yy.ravel()})
out = modelo.predict(exog)
ax.plot_surface(xx, yy,
                out.reshape(xx.shape),
                rstride=1,
                cstride=1,
                color='None',
                alpha = 0.4)
plt.show()

# %% [markdown]
# ## Ahora sí agreguemos el componente espacial en un ejemplo interesante

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.geometry import Point
import shapely.ops as ops
import matplotlib.pyplot as plt
from sklearn import metrics
import libpysal as lps # Librería de python para análisis espacial

# %%
valor_ref = gpd.read_file('zip://data/valor_ref.zip', encoding = 'utf-8')

# %%
valor_ref
# Out:
#         MANCODIGO      V_REF         AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0       009109014  1420000.0  2016-01-01  5.564496e-07   0.003106
# 1       009111022  2200000.0  2016-01-01  2.032584e-06   0.005819
# 2       009111025  2100000.0  2016-01-01  5.573527e-07   0.003223
# 3       009113030   800000.0  2016-01-01  8.663016e-06   0.021766
# 4       009115041  2200000.0  2016-01-01  1.032727e-06   0.004514
# ...           ...        ...         ...           ...        ...
# 351154  009263012   800000.0  2019-01-01  5.627646e-08   0.001630
# 351155  001334003   800000.0  2019-01-01  1.253352e-07   0.001608
# 351156  001334004   800000.0  2019-01-01  1.448474e-07   0.001784
# 351157  001334005   800000.0  2019-01-01  8.258598e-08   0.001196
# 351158  001334006   800000.0  2019-01-01  8.232622e-08   0.001194
#
#                                                  geometry
# 0       POLYGON ((-74.07808 4.70739, -74.07808 4.70726...
# 1       POLYGON ((-74.06901 4.70363, -74.06933 4.70355...
# 2       POLYGON ((-74.06507 4.70105, -74.06507 4.70105...
# 3       POLYGON ((-74.06706 4.76573, -74.06760 4.76499...
# 4       POLYGON ((-74.07292 4.72923, -74.07292 4.72895...
# ...                                                   ...
# 351154  POLYGON ((-74.08695 4.72418, -74.08692 4.72417...
# 351155  POLYGON ((-74.08244 4.53237, -74.08245 4.53236...
# 351156  POLYGON ((-74.08269 4.53247, -74.08270 4.53246...
# 351157  POLYGON ((-74.08296 4.53258, -74.08297 4.53257...
# 351158  POLYGON ((-74.08321 4.53268, -74.08322 4.53267...
#
# [351159 rows x 6 columns]

# %%
valor_ref.sort_values('AÑO', inplace=True)

# %%
valor_ref = valor_ref.drop_duplicates(subset=['MANCODIGO'], keep='last')

# %%
valor_ref.plot();

# %%
valor_ref['AÑO'] = pd.to_datetime(valor_ref['AÑO'])
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/motus/lib/python3.7/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
valor_ref['AÑO'].dt.year
# Out:
# 76120     2018
# 279701    2018
# 64623     2018
# 76182     2018
# 79199     2018
#           ...
# 321930    2019
# 321931    2019
# 321932    2019
# 321924    2019
# 351158    2019
# Name: AÑO, Length: 43978, dtype: int64

# %%
base_filtrada = valor_ref[valor_ref['AÑO'] == '2018-01-01']

# %%
valor_ref.query('AÑO == "2018-01-01"')
# Out:
#         MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 76120   006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 279701  204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 64623   005617073   690000.0 2018-01-01  5.045286e-07   0.003274
# 76182   006516032  1280000.0 2018-01-01  2.334169e-07   0.002315
# 79199   005640022   105000.0 2018-01-01  9.936744e-08   0.002587
# ...           ...        ...        ...           ...        ...
# 262198  204106029        0.0 2018-01-01  4.751356e-08   0.000872
# 262170  005617061   690000.0 2018-01-01  8.168417e-08   0.001416
# 137420  005617078   690000.0 2018-01-01  8.384211e-08   0.001973
# 137678  205322029        0.0 2018-01-01  1.597609e-06   0.005220
# 133538  002514034   700000.0 2018-01-01  1.055454e-07   0.001409
#
#                                                  geometry
# 76120   POLYGON ((-74.14415 4.67786, -74.14419 4.67782...
# 279701  POLYGON ((-74.16309 4.54659, -74.16311 4.54654...
# 64623   POLYGON ((-74.09980 4.71050, -74.10054 4.71001...
# 76182   POLYGON ((-74.16022 4.65237, -74.16022 4.65237...
# 79199   POLYGON ((-74.11112 4.72036, -74.11128 4.72011...
# ...                                                   ...
# 262198  POLYGON ((-74.16383 4.54653, -74.16385 4.54648...
# 262170  POLYGON ((-74.09820 4.71175, -74.09829 4.71165...
# 137420  POLYGON ((-74.10230 4.70713, -74.10226 4.70709...
# 137678  POLYGON ((-74.20795 4.62623, -74.20796 4.62623...
# 133538  POLYGON ((-74.13640 4.56002, -74.13643 4.55998...
#
# [133 rows x 6 columns]

# %%
valor_ref['V_REF'].plot.hist(bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
valor_ref['V_REF'].describe()
# Out:
# count    4.397800e+04
# mean     1.523453e+06
# std      1.105929e+06
# min      0.000000e+00
# 25%      7.000000e+05
# 50%      1.451000e+06
# 75%      2.180000e+06
# max      2.710000e+07
# Name: V_REF, dtype: float64

# %%
shp_bog = gpd.read_file("data/Localidades", encoding = "utf-8")
shp_bog = shp_bog.set_index('LocNombre', drop=True)
shp_bog.crs = {'init' :'epsg:4326'}
shp_bog = shp_bog.drop('SUMAPAZ',axis=0) 
bogota = ops.cascaded_union(shp_bog['geometry'])
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/motus/lib/python3.7/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
valor_ref = valor_ref[valor_ref.within(bogota)]

# %%
valor_ref.head()
# Out:
#    MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0  006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 1  204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 2  005617073   690000.0 2018-01-01  5.045286e-07   0.003274
# 3  006516032  1280000.0 2018-01-01  2.334169e-07   0.002315
# 4  005640022   105000.0 2018-01-01  9.936744e-08   0.002587
#
#                                             geometry  comercios
# 0  POLYGON ((-74.14415 4.67786, -74.14419 4.67782...        5.0
# 1  POLYGON ((-74.16309 4.54659, -74.16311 4.54654...        0.0
# 2  POLYGON ((-74.09980 4.71050, -74.10054 4.71001...        0.0
# 3  POLYGON ((-74.16022 4.65237, -74.16022 4.65237...       30.0
# 4  POLYGON ((-74.11112 4.72036, -74.11128 4.72011...        0.0

# %%
# Graficamos los datos por quantiles
valor_ref.plot(column='V_REF', scheme='quantiles', 
                cmap='YlOrRd', k = 10, figsize = (8,12), legend=True);

# %%
valor_ref.plot(column='V_REF', cmap='YlOrRd', k  = 10,figsize = (8,12), legend=True);

# %%
valor_ref
# Out:
#         MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 76120   006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 279701  204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 64623   005617073   690000.0 2018-01-01  5.045286e-07   0.003274
# 76182   006516032  1280000.0 2018-01-01  2.334169e-07   0.002315
# 79199   005640022   105000.0 2018-01-01  9.936744e-08   0.002587
# ...           ...        ...        ...           ...        ...
# 321930  009254040  1400000.0 2019-01-01  1.954736e-07   0.002237
# 321931  004601011  1550000.0 2019-01-01  1.074950e-07   0.001552
# 321932  004581089   797000.0 2019-01-01  1.717022e-07   0.001651
# 321924  002516007   850000.0 2019-01-01  2.728571e-07   0.002243
# 351158  001334006   800000.0 2019-01-01  8.232622e-08   0.001194
#
#                                                  geometry
# 76120   POLYGON ((-74.14415 4.67786, -74.14419 4.67782...
# 279701  POLYGON ((-74.16309 4.54659, -74.16311 4.54654...
# 64623   POLYGON ((-74.09980 4.71050, -74.10054 4.71001...
# 76182   POLYGON ((-74.16022 4.65237, -74.16022 4.65237...
# 79199   POLYGON ((-74.11112 4.72036, -74.11128 4.72011...
# ...                                                   ...
# 321930  POLYGON ((-74.11971 4.74375, -74.11979 4.74371...
# 321931  POLYGON ((-74.16767 4.64133, -74.16770 4.64131...
# 321932  POLYGON ((-74.16091 4.61508, -74.16092 4.61508...
# 321924  POLYGON ((-74.13449 4.55521, -74.13449 4.55515...
# 351158  POLYGON ((-74.08321 4.53268, -74.08322 4.53267...
#
# [43914 rows x 6 columns]

# %%
#### ----- Eliminar outlayers ------ #######
valor_ref = valor_ref[np.abs(valor_ref['V_REF'] - valor_ref['V_REF'].mean())<2.5*valor_ref['V_REF'].std()]
valor_ref = valor_ref.reset_index(drop = True)

# %%
valor_ref['V_REF'].plot.hist(bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
comercios = pd.read_pickle('data/comercios.p', 'gzip')

# %%
comercios
# Out:
#                                                Nombre  \
# 0                              PROCOLOMBIA VERDE 2000
# 0                                    TIENDA DONAANA S
# 0                              JANNETH CLAVIJO MEDINA
# 0                      CENTRO COMERCIAL ES LA OCASION
# 0                        ENSENANDO PARA CAMBIAR VIDAS
# ..                                                ...
# 0                                             MAX OIL
# 0                               PELUQUERIA PEINARTE M
# 0                             TECNO GESTION E  H LTDA
# 0   UNIDAD MEDICA DIAGNOSTICA ESPINOSA GOMEZ SEDE ...
# 0                                          SIMONIZCAR
#
#                                             Actividad  \
# 0   Actividades de organizaciones y entidades extr...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0   Actividades de organizaciones y entidades extr...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0   Actividades de atencionde la salud humana y de...
# ..                                                ...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0                      Otras actividades de servicios
# 0                        Informacion y comunicaciones
# 0   Actividades de atencionde la salud humana y de...
# 0   Comercio al por mayor y al por menor; reparaci...
#
#                          Direccion  Latitude  Longitude  \
# 0             CLL 142 C NO. 105-14  4.745081 -74.095978
# 0                 CL 129 NO. 92 18  4.724225 -74.090756
# 0   CR  3 A BIS ESTE NO. 46-23 SUR  4.545500 -74.095982
# 0                  CL 11 NO. 11-79  4.600716 -74.079492
# 0                  CLL 3 NO. 24-62  4.598504 -74.095967
# ..                             ...       ...        ...
# 0          CLL  187 A   8 C  -  91  4.763988 -74.031128
# 0            CR 91 . 135 B 40 LC 1  4.726879 -74.084389
# 0               CRA 7B NO 123 - 46  4.699600 -74.031125
# 0            CR 7 B NO. 124 05 P 2  4.700447 -74.031119
# 0             CR 97 . 24B-35 IN 60  4.681108 -74.131378
#
#                      geometry
# 0   POINT (-74.09598 4.74508)
# 0   POINT (-74.09076 4.72423)
# 0   POINT (-74.09598 4.54550)
# 0   POINT (-74.07949 4.60072)
# 0   POINT (-74.09597 4.59850)
# ..                        ...
# 0   POINT (-74.03113 4.76399)
# 0   POINT (-74.08439 4.72688)
# 0   POINT (-74.03113 4.69960)
# 0   POINT (-74.03112 4.70045)
# 0   POINT (-74.13138 4.68111)
#
# [439887 rows x 6 columns]

# %%
comercios = gpd.GeoDataFrame(comercios, geometry = comercios[['Longitude', 'Latitude']].apply(Point, axis=1), 
                             crs = {'init':'epsg:4326'})
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/motus/lib/python3.7/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
comercios
# Out:
#                                                Nombre  \
# 0                              PROCOLOMBIA VERDE 2000
# 0                                    TIENDA DONAANA S
# 0                              JANNETH CLAVIJO MEDINA
# 0                      CENTRO COMERCIAL ES LA OCASION
# 0                        ENSENANDO PARA CAMBIAR VIDAS
# ..                                                ...
# 0                                             MAX OIL
# 0                               PELUQUERIA PEINARTE M
# 0                             TECNO GESTION E  H LTDA
# 0   UNIDAD MEDICA DIAGNOSTICA ESPINOSA GOMEZ SEDE ...
# 0                                          SIMONIZCAR
#
#                                             Actividad  \
# 0   Actividades de organizaciones y entidades extr...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0   Actividades de organizaciones y entidades extr...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0   Actividades de atencionde la salud humana y de...
# ..                                                ...
# 0   Comercio al por mayor y al por menor; reparaci...
# 0                      Otras actividades de servicios
# 0                        Informacion y comunicaciones
# 0   Actividades de atencionde la salud humana y de...
# 0   Comercio al por mayor y al por menor; reparaci...
#
#                          Direccion  Latitude  Longitude  \
# 0             CLL 142 C NO. 105-14  4.745081 -74.095978
# 0                 CL 129 NO. 92 18  4.724225 -74.090756
# 0   CR  3 A BIS ESTE NO. 46-23 SUR  4.545500 -74.095982
# 0                  CL 11 NO. 11-79  4.600716 -74.079492
# 0                  CLL 3 NO. 24-62  4.598504 -74.095967
# ..                             ...       ...        ...
# 0          CLL  187 A   8 C  -  91  4.763988 -74.031128
# 0            CR 91 . 135 B 40 LC 1  4.726879 -74.084389
# 0               CRA 7B NO 123 - 46  4.699600 -74.031125
# 0            CR 7 B NO. 124 05 P 2  4.700447 -74.031119
# 0             CR 97 . 24B-35 IN 60  4.681108 -74.131378
#
#                      geometry
# 0   POINT (-74.09598 4.74508)
# 0   POINT (-74.09076 4.72423)
# 0   POINT (-74.09598 4.54550)
# 0   POINT (-74.07949 4.60072)
# 0   POINT (-74.09597 4.59850)
# ..                        ...
# 0   POINT (-74.03113 4.76399)
# 0   POINT (-74.08439 4.72688)
# 0   POINT (-74.03113 4.69960)
# 0   POINT (-74.03112 4.70045)
# 0   POINT (-74.13138 4.68111)
#
# [439887 rows x 6 columns]

# %%
# %%time
comercios.plot(markersize = 0.01)
# Out:
# CPU times: user 29.7 s, sys: 149 ms, total: 29.9 s
# Wall time: 29.9 s
# <AxesSubplot:>

# %%
##### ----- Agregar el numero de comercios que existen ------- ######
comercios_man = gpd.sjoin(valor_ref, comercios)
comercios_man = comercios_man.groupby(['MANCODIGO']).size()
comercios_man = comercios_man.reset_index(name = 'comercios')

valor_ref = valor_ref.merge(comercios_man, how='left')
valor_ref.fillna({'comercios': 0}, inplace = True)
# Out:
# /Users/germangonzalez/.pyenv/versions/3.7.5/envs/motus/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs

# %%
comercios_man
# Out:
#        MANCODIGO  comercios
# 0      001101001          5
# 1      001101002         22
# 2      001101003          6
# 3      001101004          4
# 4      001101005         12
# ...          ...        ...
# 33255  208203082          1
# 33256  208203086          5
# 33257  208203092          3
# 33258  208203093          2
# 33259  208203095          1
#
# [33260 rows x 2 columns]

# %% [markdown]
# ### Ahora los resultados con comercios

# %%
valor_ref
# Out:
#        MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0      006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 1      204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 2      005617073   690000.0 2018-01-01  5.045286e-07   0.003274
# 3      006516032  1280000.0 2018-01-01  2.334169e-07   0.002315
# 4      005640022   105000.0 2018-01-01  9.936744e-08   0.002587
# ...          ...        ...        ...           ...        ...
# 42817  009254040  1400000.0 2019-01-01  1.954736e-07   0.002237
# 42818  004601011  1550000.0 2019-01-01  1.074950e-07   0.001552
# 42819  004581089   797000.0 2019-01-01  1.717022e-07   0.001651
# 42820  002516007   850000.0 2019-01-01  2.728571e-07   0.002243
# 42821  001334006   800000.0 2019-01-01  8.232622e-08   0.001194
#
#                                                 geometry  comercios
# 0      POLYGON ((-74.14415 4.67786, -74.14419 4.67782...        5.0
# 1      POLYGON ((-74.16309 4.54659, -74.16311 4.54654...        0.0
# 2      POLYGON ((-74.09980 4.71050, -74.10054 4.71001...        0.0
# 3      POLYGON ((-74.16022 4.65237, -74.16022 4.65237...       30.0
# 4      POLYGON ((-74.11112 4.72036, -74.11128 4.72011...        0.0
# ...                                                  ...        ...
# 42817  POLYGON ((-74.11971 4.74375, -74.11979 4.74371...        5.0
# 42818  POLYGON ((-74.16767 4.64133, -74.16770 4.64131...        2.0
# 42819  POLYGON ((-74.16091 4.61508, -74.16092 4.61508...        0.0
# 42820  POLYGON ((-74.13449 4.55521, -74.13449 4.55515...        3.0
# 42821  POLYGON ((-74.08321 4.53268, -74.08322 4.53267...        0.0
#
# [42822 rows x 7 columns]

# %%
plt.scatter(valor_ref['comercios'], valor_ref['V_REF'], s = 0.2)

# %%
#### ------ Crear variable ----- ####
valor_ref['comercios_sq'] = valor_ref['comercios']**2

# %% [markdown]
# ## Agregar variable estrato

# %%
estrato = gpd.read_file('data/manzanaestratificacion/ManzanaEstratificacion.shp')
estrato.crs = {'init': 'epsg:4326'}
valor_ref = gpd.sjoin(valor_ref, estrato[['ESTRATO', 'geometry']]).drop_duplicates(subset='MANCODIGO', keep='first')
plt.scatter(valor_ref['ESTRATO'], valor_ref['V_REF'], s = 0.2)

# %%
valor_ref.drop(columns = 'index_right')
# Out:
#        MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0      006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 1      204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 5      204106037        0.0 2018-01-01  1.188792e-07   0.001674
# 7      204106050        0.0 2018-01-01  1.202692e-07   0.001678
# 8      204106076        0.0 2018-01-01  5.929767e-08   0.000989
# ...          ...        ...        ...           ...        ...
# 42816  009254037  1400000.0 2019-01-01  2.010001e-07   0.002312
# 42817  009254040  1400000.0 2019-01-01  1.954736e-07   0.002237
# 42818  004601011  1550000.0 2019-01-01  1.074950e-07   0.001552
# 42819  004581089   797000.0 2019-01-01  1.717022e-07   0.001651
# 42820  002516007   850000.0 2019-01-01  2.728571e-07   0.002243
#
#                                                 geometry  comercios  \
# 0      POLYGON ((-74.14415 4.67786, -74.14419 4.67782...        5.0
# 1      POLYGON ((-74.16309 4.54659, -74.16311 4.54654...        0.0
# 5      POLYGON ((-74.16486 4.54608, -74.16492 4.54600...        0.0
# 7      POLYGON ((-74.16479 4.54712, -74.16484 4.54714...        0.0
# 8      POLYGON ((-74.16425 4.54769, -74.16427 4.54765...        1.0
# ...                                                  ...        ...
# 42816  POLYGON ((-74.11822 4.74458, -74.11824 4.74454...       12.0
# 42817  POLYGON ((-74.11971 4.74375, -74.11979 4.74371...        5.0
# 42818  POLYGON ((-74.16767 4.64133, -74.16770 4.64131...        2.0
# 42819  POLYGON ((-74.16091 4.61508, -74.16092 4.61508...        0.0
# 42820  POLYGON ((-74.13449 4.55521, -74.13449 4.55515...        3.0
#
#        comercios_sq  ESTRATO
# 0              25.0        3
# 1               0.0        1
# 5               0.0        1
# 7               0.0        1
# 8               1.0        1
# ...             ...      ...
# 42816         144.0        2
# 42817          25.0        2
# 42818           4.0        2
# 42819           0.0        0
# 42820           9.0        2
#
# [42499 rows x 9 columns]

# %%
# !pip install spreg
# Out:
# Requirement already satisfied: spreg in c:\programdata\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.3 in c:\programdata\anaconda3\lib\site-packages (from spreg) (1.16.5)
# Requirement already satisfied: scipy>=0.11 in c:\programdata\anaconda3\lib\site-packages (from spreg) (1.3.1)
# Requirement already satisfied: libpysal>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from spreg) (4.2.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from spreg) (0.25.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from libpysal>=4.0.0->spreg) (2.10.3)
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (from libpysal>=4.0.0->spreg) (0.0.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from libpysal>=4.0.0->spreg) (2.22.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->spreg) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->spreg) (2019.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->libpysal>=4.0.0->spreg) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4->libpysal>=4.0.0->spreg) (4.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->libpysal>=4.0.0->spreg) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->libpysal>=4.0.0->spreg) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->libpysal>=4.0.0->spreg) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->libpysal>=4.0.0->spreg) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->spreg) (1.12.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4->libpysal>=4.0.0->spreg) (1.9.3)

# %%
import spreg

# %% [markdown]
# ## Regresión lineal base (sin incluir información espacial)
#
# $$
# \Large
# \begin{equation}
# Valor_i = \alpha + \beta_1*comercios + \beta_2*comercios^2 + \beta_3*estrato
# \end{equation}
# $$

# %%
np.array(valor_ref['V_REF'])[:, np.newaxis]
# Out:
# array([[1450000.],
#        [      0.],
#        [      0.],
#        ...,
#        [1550000.],
#        [ 797000.],
#        [ 850000.]])

# %%
y = np.array(valor_ref['V_REF'])[:, np.newaxis]

# %%
X = np.array(valor_ref[['comercios', 'comercios_sq', 'ESTRATO']])

# %%
X
# Out:
# array([[ 5., 25.,  3.],
#        [ 0.,  0.,  1.],
#        [ 0.,  0.,  1.],
#        ...,
#        [ 2.,  4.,  2.],
#        [ 0.,  0.,  0.],
#        [ 3.,  9.,  2.]])

# %%
modelo_ols = spreg.OLS(y, X, name_y = 'Valor m2', name_x = ['comercios', 'comercias cuadrado', 'estrato'])

# %%
modelo = {'modelo': modelo_ols,
         'datos': valor_ref}

# %%
import pickle
pickle.dump(modelo, open('modelo.p', 'wb'))

# %%
print(modelo_ols.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :    Valor m2                Number of Observations:       42499
# Mean dependent var  :1427022.6804                Number of Variables   :           4
# S.D. dependent var  : 832721.0443                Degrees of Freedom    :       42495
# R-squared           :      0.4919
# Adjusted R-squared  :      0.4919
# Sum squared residual:14972360644140308.000                F-statistic           :  13715.0708
# Sigma-square        :352332289543.248                Prob(F-statistic)     :           0
# S.E. of regression  :  593575.850                Log likelihood        : -625279.787
# Sigma-square ML     :352299128076.903                Akaike info criterion : 1250567.574
# S.E of regression ML: 593547.9156                Schwarz criterion     : 1250602.203
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    492859.1730099    5691.2401775      86.5996088       0.0000000
#            comercios    19361.0933063     237.1910134      81.6265887       0.0000000
#   comercias cuadrado     -27.7933892       0.5823251     -47.7283008       0.0000000
#              estrato    381434.1980742    2522.7624754     151.1970317       0.0000000
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            4.199
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2       11263.404           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                3        3688.688           0.0000
# Koenker-Bassett test              3        1689.556           0.0000
# ================================ END OF REPORT =====================================

# %%
modelo_ols.predy
# Out:
# array([[1733272.39903478],
#        [ 874293.37108415],
#        [ 874293.37108415],
#        ...,
#        [1294338.5822143 ],
#        [ 492859.17300995],
#        [1313560.70857474]])

# %%
metricas = ['RMSE: {:.3f}'.format(np.sqrt(metrics.mean_squared_error(valor_ref['V_REF'], modelo_ols.predy))),
            'MAE: {:.3f}'.format(metrics.mean_absolute_error(valor_ref['V_REF'], modelo_ols.predy))]

plt.figure(figsize = (12,8))
plt.scatter(valor_ref['V_REF'], modelo_ols.predy, s = 0.1, label = '\n'.join(metricas))
plt.plot([-0.2, 5e6], [-0.2, 5e6], color = 'black', linestyle = 'dotted')
plt.xlabel('Valor real')
plt.ylabel('Valor predicho')
plt.legend(loc = 'lower right')
plt.title('Valores reales y predichos metro cuadrado OLS \n Manzanas de entrenamiento en Bogotá', fontsize=16);

# %% [markdown]
# ## Predictores laggeados (WX):
#
# $$
# \Large
# \begin{equation}
# Valor_i = \alpha + \beta X_i + \delta \sum_j w_{ij} X'_i
# \end{equation}
# $$

# %%
knnW = lps.weights.KNN.from_dataframe(valor_ref, k = 8)
knnW.transform = 'r'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\libpysal\weights\weights.py:167: UserWarning: The weights matrix is not fully connected:
#  There are 7 disconnected components.
#   warnings.warn(message)

# %%
valor_ref['comercios_lag'] = lps.weights.lag_spatial(knnW, valor_ref['comercios'])
valor_ref['estrato_lag'] = lps.weights.lag_spatial(knnW, valor_ref['ESTRATO'])

# %%
valor_ref
# Out:
#        MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0      006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 1      204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 5      204106037        0.0 2018-01-01  1.188792e-07   0.001674
# 7      204106050        0.0 2018-01-01  1.202692e-07   0.001678
# 8      204106076        0.0 2018-01-01  5.929767e-08   0.000989
# ...          ...        ...        ...           ...        ...
# 42816  009254037  1400000.0 2019-01-01  2.010001e-07   0.002312
# 42817  009254040  1400000.0 2019-01-01  1.954736e-07   0.002237
# 42818  004601011  1550000.0 2019-01-01  1.074950e-07   0.001552
# 42819  004581089   797000.0 2019-01-01  1.717022e-07   0.001651
# 42820  002516007   850000.0 2019-01-01  2.728571e-07   0.002243
#
#                                                 geometry  comercios  \
# 0      POLYGON ((-74.14415 4.67786, -74.14419 4.67782...        5.0
# 1      POLYGON ((-74.16309 4.54659, -74.16311 4.54654...        0.0
# 5      POLYGON ((-74.16486 4.54608, -74.16492 4.54600...        0.0
# 7      POLYGON ((-74.16479 4.54712, -74.16484 4.54714...        0.0
# 8      POLYGON ((-74.16425 4.54769, -74.16427 4.54765...        1.0
# ...                                                  ...        ...
# 42816  POLYGON ((-74.11822 4.74458, -74.11824 4.74454...       12.0
# 42817  POLYGON ((-74.11971 4.74375, -74.11979 4.74371...        5.0
# 42818  POLYGON ((-74.16767 4.64133, -74.16770 4.64131...        2.0
# 42819  POLYGON ((-74.16091 4.61508, -74.16092 4.61508...        0.0
# 42820  POLYGON ((-74.13449 4.55521, -74.13449 4.55515...        3.0
#
#        comercios_sq  index_right  ESTRATO  comercios_lag  estrato_lag
# 0              25.0        34175        3         11.000        3.000
# 1               0.0        22545        1          0.000        1.000
# 5               0.0        22545        1          0.000        1.000
# 7               0.0        22545        1          0.125        1.000
# 8               1.0        22545        1          2.125        1.000
# ...             ...          ...      ...            ...          ...
# 42816         144.0        31547        2          6.750        2.000
# 42817          25.0        31564        2          2.625        2.000
# 42818           4.0        35546        2          5.375        2.000
# 42819           0.0        13941        0         10.125        2.625
# 42820           9.0        40386        2          2.500        1.500
#
# [42499 rows x 12 columns]

# %%
X = np.array(valor_ref[['comercios', 'comercios_sq', 'ESTRATO', 'comercios_lag', 'estrato_lag']])

# %%
modelo_ols_lag = spreg.OLS(y, X, name_y = 'Valor m2', name_x = ['comercios', 'comercios_sq', 'ESTRATO', 'comercios_lag', 'estrato_lag'])

# %%
print(modelo_ols_lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :    Valor m2                Number of Observations:       42499
# Mean dependent var  :1427022.6804                Number of Variables   :           6
# S.D. dependent var  : 832721.0443                Degrees of Freedom    :       42493
# R-squared           :      0.5452
# Adjusted R-squared  :      0.5452
# Sum squared residual:13402421654468280.000                F-statistic           :  10188.0600
# Sigma-square        :315403046489.264                Prob(F-statistic)     :           0
# S.E. of regression  :  561607.556                Log likelihood        : -622925.970
# Sigma-square ML     :315358517952.617                Akaike info criterion : 1245863.940
# S.E of regression ML: 561567.9104                Schwarz criterion     : 1245915.883
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    242141.9522065    6745.2642794      35.8980675       0.0000000
#            comercios    12330.3937328     282.0115217      43.7230141       0.0000000
#         comercios_sq     -19.1091367       0.5836839     -32.7388429       0.0000000
#              ESTRATO    255851.5674122    3278.0140055      78.0507853       0.0000000
#        comercios_lag    11359.5137317     337.5780751      33.6500341       0.0000000
#          estrato_lag    229915.7487146    4402.2408630      52.2269807       0.0000000
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            8.573
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        8481.418           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                5        3386.103           0.0000
# Koenker-Bassett test              5        1652.689           0.0000
# ================================ END OF REPORT =====================================

# %%
metricas = ['RMSE: {:.3f}'.format(np.sqrt(metrics.mean_squared_error(valor_ref['V_REF'], modelo_ols_lag.predy))),
            'MAE: {:.3f}'.format(metrics.mean_absolute_error(valor_ref['V_REF'], modelo_ols_lag.predy))]

plt.figure(figsize = (12,8))
plt.scatter(valor_ref['V_REF'], modelo_ols_lag.predy, s = 0.1, label = '\n'.join(metricas))
plt.plot([-0.2,5e6], [-0.2,5e6], color = 'black', linestyle = 'dotted')
plt.xlabel('Eventos reales')
plt.ylabel('Eventos predichos')
plt.legend(loc = 'lower right')
plt.title('Valores reales y predichos metro cuadrado OLS lag comercios \n Manzanas de entrenamiento en Bogotá', fontsize=16);

# %% [markdown]
# ## Variable objetivo lag como predictor (WY)
#
# $$
# \Large
# \begin{equation}
# Valor_i = \alpha + \beta X_i + \delta \sum_j w_{ij} X'_i + \lambda \sum_j w_{ij} Valor_i
# \end{equation}
# $$

# %%
valor_ref['valor_lag'] = lps.weights.lag_spatial(knnW, valor_ref['V_REF'])

# %%
valor_ref
# Out:
#        MANCODIGO      V_REF        AÑO    SHAPE_AREA  SHAPE_LEN  \
# 0      006410047  1450000.0 2018-01-01  2.296913e-07   0.001940
# 1      204106026        0.0 2018-01-01  4.904944e-08   0.001122
# 5      204106037        0.0 2018-01-01  1.188792e-07   0.001674
# 7      204106050        0.0 2018-01-01  1.202692e-07   0.001678
# 8      204106076        0.0 2018-01-01  5.929767e-08   0.000989
# ...          ...        ...        ...           ...        ...
# 42816  009254037  1400000.0 2019-01-01  2.010001e-07   0.002312
# 42817  009254040  1400000.0 2019-01-01  1.954736e-07   0.002237
# 42818  004601011  1550000.0 2019-01-01  1.074950e-07   0.001552
# 42819  004581089   797000.0 2019-01-01  1.717022e-07   0.001651
# 42820  002516007   850000.0 2019-01-01  2.728571e-07   0.002243
#
#                                                 geometry  comercios  \
# 0      POLYGON ((-74.14415 4.67786, -74.14419 4.67782...        5.0
# 1      POLYGON ((-74.16309 4.54659, -74.16311 4.54654...        0.0
# 5      POLYGON ((-74.16486 4.54608, -74.16492 4.54600...        0.0
# 7      POLYGON ((-74.16479 4.54712, -74.16484 4.54714...        0.0
# 8      POLYGON ((-74.16425 4.54769, -74.16427 4.54765...        1.0
# ...                                                  ...        ...
# 42816  POLYGON ((-74.11822 4.74458, -74.11824 4.74454...       12.0
# 42817  POLYGON ((-74.11971 4.74375, -74.11979 4.74371...        5.0
# 42818  POLYGON ((-74.16767 4.64133, -74.16770 4.64131...        2.0
# 42819  POLYGON ((-74.16091 4.61508, -74.16092 4.61508...        0.0
# 42820  POLYGON ((-74.13449 4.55521, -74.13449 4.55515...        3.0
#
#        comercios_sq  index_right  ESTRATO  comercios_lag  estrato_lag  \
# 0              25.0        34175        3         11.000        3.000
# 1               0.0        22545        1          0.000        1.000
# 5               0.0        22545        1          0.000        1.000
# 7               0.0        22545        1          0.125        1.000
# 8               1.0        22545        1          2.125        1.000
# ...             ...          ...      ...            ...          ...
# 42816         144.0        31547        2          6.750        2.000
# 42817          25.0        31564        2          2.625        2.000
# 42818           4.0        35546        2          5.375        2.000
# 42819           0.0        13941        0         10.125        2.625
# 42820           9.0        40386        2          2.500        1.500
#
#           valor_lag
# 0      1.656250e+06
# 1      0.000000e+00
# 5      0.000000e+00
# 7      0.000000e+00
# 8      0.000000e+00
# ...             ...
# 42816  1.260275e+06
# 42817  5.450795e+05
# 42818  1.600000e+06
# 42819  2.190000e+06
# 42820  4.412199e+05
#
# [42499 rows x 13 columns]

# %%
X = np.array(valor_ref[['comercios', 'comercios_sq', 'ESTRATO', 'comercios_lag', 'estrato_lag', 'valor_lag']])

# %%
X
# Out:
# array([[5.00000000e+00, 2.50000000e+01, 3.00000000e+00, 1.10000000e+01,
#         3.00000000e+00, 1.65625000e+06],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.00000000e+00, 4.00000000e+00, 2.00000000e+00, 5.37500000e+00,
#         2.00000000e+00, 1.60000000e+06],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.01250000e+01,
#         2.62500000e+00, 2.19000000e+06],
#        [3.00000000e+00, 9.00000000e+00, 2.00000000e+00, 2.50000000e+00,
#         1.50000000e+00, 4.41219938e+05]])

# %%
modelo_s2sls_lag = spreg.OLS(y, X, name_y = 'Valor m2', name_x = ['comercios', 'comercios_sq', 'ESTRATO', 'comercios_lag', 'estrato_lag', 'valor_lag'])

# %%
print(modelo_s2sls_lag.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :    Valor m2                Number of Observations:       42499
# Mean dependent var  :1427022.6804                Number of Variables   :           7
# S.D. dependent var  : 832721.0443                Degrees of Freedom    :       42492
# R-squared           :      0.8186
# Adjusted R-squared  :      0.8186
# Sum squared residual:5345658946033470.000                F-statistic           :  31959.1182
# Sigma-square        :125803891227.372                Prob(F-statistic)     :           0
# S.E. of regression  :  354688.442                Log likelihood        : -603394.479
# Sigma-square ML     :125783170098.908                Akaike info criterion : 1206802.959
# S.E of regression ML: 354659.2310                Schwarz criterion     : 1206863.559
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    10163.1704922    4357.5430339       2.3323167       0.0196887
#            comercios    8738.8904466     178.6715135      48.9103734       0.0000000
#         comercios_sq     -10.8681078       0.3700666     -29.3679805       0.0000000
#              ESTRATO    252275.8397424    2070.3082600     121.8542401       0.0000000
#        comercios_lag    -5210.7848337     223.0288718     -23.3637232       0.0000000
#          estrato_lag    -234364.4021222    3331.0323006     -70.3578894       0.0000000
#            valor_lag       0.9449311       0.0037339     253.0656787       0.0000000
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           11.119
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2      150645.368           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                6        9784.095           0.0000
# Koenker-Bassett test              6        1752.746           0.0000
# ================================ END OF REPORT =====================================

# %%
metricas = ['RMSE: {:.3f}'.format(np.sqrt(metrics.mean_squared_error(valor_ref['V_REF'], modelo_s2sls_lag.predy))),
            'MAE: {:.3f}'.format(metrics.mean_absolute_error(valor_ref['V_REF'], modelo_s2sls_lag.predy))]

plt.figure(figsize = (12,8))
plt.scatter(valor_ref['V_REF'], modelo_s2sls_lag.predy, s = 0.1, label = '\n'.join(metricas))
plt.plot([-0.2,5e6], [-0.2,5e6], color = 'black', linestyle = 'dotted')
plt.xlabel('Eventos reales')
plt.ylabel('Eventos predichos')
plt.legend(loc = 'lower right')
plt.title('Valores reales y predichos metro cuadrado OLS lag comercios y valor \n Manzanas de entrenamiento en Bogotá', fontsize=16);

# %%
# ?spreg.GM_Lag
# Out:
# Init signature:
# spreg.GM_Lag(
#     y,
#     x,
#     yend=None,
#     q=None,
#     w=None,
#     w_lags=1,
#     lag_q=True,
#     robust=None,
#     gwk=None,
#     sig2n_k=False,
#     spat_diag=False,
#     vm=False,
#     name_y=None,
#     name_x=None,
#     name_yend=None,
#     name_q=None,
#     name_w=None,
#     name_gwk=None,
#     name_ds=None,
# )
# Docstring:
# Spatial two stage least squares (S2SLS) with results and diagnostics;
# Anselin (1988) :cite:`Anselin1988`
#
# Parameters
# ----------
# y            : array
#                nx1 array for dependent variable
# x            : array
#                Two dimensional array with n rows and one column for each
#                independent (exogenous) variable, excluding the constant
# yend         : array
#                Two dimensional array with n rows and one column for each
#                endogenous variable
# q            : array
#                Two dimensional array with n rows and one column for each
#                external exogenous variable to use as instruments (note:
#                this should not contain any variables from x); cannot be
#                used in combination with h
# w            : pysal W object
#                Spatial weights object
# w_lags       : integer
#                Orders of W to include as instruments for the spatially
#                lagged dependent variable. For example, w_lags=1, then
#                instruments are WX; if w_lags=2, then WX, WWX; and so on.
# lag_q        : boolean
#                If True, then include spatial lags of the additional
#                instruments (q).
# robust       : string
#                If 'white', then a White consistent estimator of the
#                variance-covariance matrix is given.  If 'hac', then a
#                HAC consistent estimator of the variance-covariance
#                matrix is given. Default set to None.
# gwk          : pysal W object
#                Kernel spatial weights needed for HAC estimation. Note:
#                matrix must have ones along the main diagonal.
# sig2n_k      : boolean
#                If True, then use n-k to estimate sigma^2. If False, use n.
# spat_diag    : boolean
#                If True, then compute Anselin-Kelejian test
# vm           : boolean
#                If True, include variance-covariance matrix in summary
#                results
# name_y       : string
#                Name of dependent variable for use in output
# name_x       : list of strings
#                Names of independent variables for use in output
# name_yend    : list of strings
#                Names of endogenous variables for use in output
# name_q       : list of strings
#                Names of instruments for use in output
# name_w       : string
#                Name of weights matrix for use in output
# name_gwk     : string
#                Name of kernel weights matrix for use in output
# name_ds      : string
#                Name of dataset for use in output
#
# Attributes
# ----------
# summary      : string
#                Summary of regression results and diagnostics (note: use in
#                conjunction with the print command)
# betas        : array
#                kx1 array of estimated coefficients
# u            : array
#                nx1 array of residuals
# e_pred       : array
#                nx1 array of residuals (using reduced form)
# predy        : array
#                nx1 array of predicted y values
# predy_e      : array
#                nx1 array of predicted y values (using reduced form)
# n            : integer
#                Number of observations
# k            : integer
#                Number of variables for which coefficients are estimated
#                (including the constant)
# kstar        : integer
#                Number of endogenous variables.
# y            : array
#                nx1 array for dependent variable
# x            : array
#                Two dimensional array with n rows and one column for each
#                independent (exogenous) variable, including the constant
# yend         : array
#                Two dimensional array with n rows and one column for each
#                endogenous variable
# q            : array
#                Two dimensional array with n rows and one column for each
#                external exogenous variable used as instruments
# z            : array
#                nxk array of variables (combination of x and yend)
# h            : array
#                nxl array of instruments (combination of x and q)
# robust       : string
#                Adjustment for robust standard errors
# mean_y       : float
#                Mean of dependent variable
# std_y        : float
#                Standard deviation of dependent variable
# vm           : array
#                Variance covariance matrix (kxk)
# pr2          : float
#                Pseudo R squared (squared correlation between y and ypred)
# pr2_e        : float
#                Pseudo R squared (squared correlation between y and ypred_e
#                (using reduced form))
# utu          : float
#                Sum of squared residuals
# sig2         : float
#                Sigma squared used in computations
# std_err      : array
#                1xk array of standard errors of the betas
# z_stat       : list of tuples
#                z statistic; each tuple contains the pair (statistic,
#                p-value), where each is a float
# ak_test      : tuple
#                Anselin-Kelejian test; tuple contains the pair (statistic,
#                p-value)
# name_y       : string
#                Name of dependent variable for use in output
# name_x       : list of strings
#                Names of independent variables for use in output
# name_yend    : list of strings
#                Names of endogenous variables for use in output
# name_z       : list of strings
#                Names of exogenous and endogenous variables for use in
#                output
# name_q       : list of strings
#                Names of external instruments
# name_h       : list of strings
#                Names of all instruments used in ouput
# name_w       : string
#                Name of weights matrix for use in output
# name_gwk     : string
#                Name of kernel weights matrix for use in output
# name_ds      : string
#                Name of dataset for use in output
# title        : string
#                Name of the regression method used
# sig2n        : float
#                Sigma squared (computed with n in the denominator)
# sig2n_k      : float
#                Sigma squared (computed with n-k in the denominator)
# hth          : float
#                :math:`H'H`
# hthi         : float
#                :math:`(H'H)^{-1}`
# varb         : array
#                :math:`(Z'H (H'H)^{-1} H'Z)^{-1}`
# zthhthi      : array
#                :math:`Z'H(H'H)^{-1}`
# pfora1a2     : array
#                n(zthhthi)'varb
#
#
# Examples
# --------
#
# We first need to import the needed modules, namely numpy to convert the
# data we read into arrays that ``spreg`` understands and ``pysal`` to
# perform all the analysis. Since we will need some tests for our
# model, we also import the diagnostics module.
#
# >>> import numpy as np
# >>> import libpysal
# >>> import spreg
#
# Open data on Columbus neighborhood crime (49 areas) using libpysal.io.open().
# This is the DBF associated with the Columbus shapefile.  Note that
# libpysal.io.open() also reads data in CSV format; since the actual class
# requires data to be passed in as numpy arrays, the user can read their
# data in using any method.
#
# >>> db = libpysal.io.open(libpysal.examples.get_path("columbus.dbf"),'r')
#
# Extract the HOVAL column (home value) from the DBF file and make it the
# dependent variable for the regression. Note that PySAL requires this to be
# an numpy array of shape (n, 1) as opposed to the also common shape of (n, )
# that other packages accept.
#
# >>> y = np.array(db.by_col("HOVAL"))
# >>> y = np.reshape(y, (49,1))
#
# Extract INC (income) and CRIME (crime rates) vectors from the DBF to be used as
# independent variables in the regression.  Note that PySAL requires this to
# be an nxj numpy array, where j is the number of independent variables (not
# including a constant). By default this model adds a vector of ones to the
# independent variables passed in, but this can be overridden by passing
# constant=False.
#
# >>> X = []
# >>> X.append(db.by_col("INC"))
# >>> X.append(db.by_col("CRIME"))
# >>> X = np.array(X).T
#
# Since we want to run a spatial error model, we need to specify the spatial
# weights matrix that includes the spatial configuration of the observations
# into the error component of the model. To do that, we can open an already
# existing gal file or create a new one. In this case, we will create one
# from ``columbus.shp``.
#
# >>> w = libpysal.weights.Rook.from_shapefile(libpysal.examples.get_path("columbus.shp"))
#
# Unless there is a good reason not to do it, the weights have to be
# row-standardized so every row of the matrix sums to one. Among other
# things, this allows to interpret the spatial lag of a variable as the
# average value of the neighboring observations. In PySAL, this can be
# easily performed in the following way:
#
# >>> w.transform = 'r'
#
# This class runs a lag model, which means that includes the spatial lag of
# the dependent variable on the right-hand side of the equation. If we want
# to have the names of the variables printed in the
# output summary, we will have to pass them in as well, although this is
# optional. The default most basic model to be run would be:
#
# >>> from spreg import GM_Lag
# >>> np.set_printoptions(suppress=True) #prevent scientific format
# >>> reg=GM_Lag(y, X, w=w, w_lags=2, name_x=['inc', 'crime'], name_y='hoval', name_ds='columbus')
# >>> reg.betas
# array([[45.30170561],
#        [ 0.62088862],
#        [-0.48072345],
#        [ 0.02836221]])
#
# Once the model is run, we can obtain the standard error of the coefficient
# estimates by calling the diagnostics module:
#
# >>> spreg.se_betas(reg)
# array([17.91278862,  0.52486082,  0.1822815 ,  0.31740089])
#
# But we can also run models that incorporates corrected standard errors
# following the White procedure. For that, we will have to include the
# optional parameter ``robust='white'``:
#
# >>> reg=GM_Lag(y, X, w=w, w_lags=2, robust='white', name_x=['inc', 'crime'], name_y='hoval', name_ds='columbus')
# >>> reg.betas
# array([[45.30170561],
#        [ 0.62088862],
#        [-0.48072345],
#        [ 0.02836221]])
#
# And we can access the standard errors from the model object:
#
# >>> reg.std_err
# array([20.47077481,  0.50613931,  0.20138425,  0.38028295])
#
# The class is flexible enough to accomodate a spatial lag model that,
# besides the spatial lag of the dependent variable, includes other
# non-spatial endogenous regressors. As an example, we will assume that
# CRIME is actually endogenous and we decide to instrument for it with
# DISCBD (distance to the CBD). We reload the X including INC only and
# define CRIME as endogenous and DISCBD as instrument:
#
# >>> X = np.array(db.by_col("INC"))
# >>> X = np.reshape(X, (49,1))
# >>> yd = np.array(db.by_col("CRIME"))
# >>> yd = np.reshape(yd, (49,1))
# >>> q = np.array(db.by_col("DISCBD"))
# >>> q = np.reshape(q, (49,1))
#
# And we can run the model again:
#
# >>> reg=GM_Lag(y, X, w=w, yend=yd, q=q, w_lags=2, name_x=['inc'], name_y='hoval', name_yend=['crime'], name_q=['discbd'], name_ds='columbus')
# >>> reg.betas
# array([[100.79359082],
#        [ -0.50215501],
#        [ -1.14881711],
#        [ -0.38235022]])
#
# Once the model is run, we can obtain the standard error of the coefficient
# estimates by calling the diagnostics module:
#
# >>> spreg.se_betas(reg)
# array([53.0829123 ,  1.02511494,  0.57589064,  0.59891744])
# File:           c:\programdata\anaconda3\lib\site-packages\spreg\twosls_sp.py
# Type:           type
# Subclasses:

# %%
from tabulate import tabulate

# %%
print(tabulate([['MAE OLS Base:', metrics.mean_absolute_error(valor_ref['V_REF'], modelo_ols.predy)],
               ['MAE OLS lag comercios:', metrics.mean_absolute_error(valor_ref['V_REF'], modelo_ols_lag.predy)],
               ['MAE OLS lag comercios + lag valor:', metrics.mean_absolute_error(valor_ref['V_REF'], modelo_s2sls_lag.predy)]]))

# %% [markdown]
# ## Otros modelos
#
# <img src="https://dataconomy.com/wp-content/uploads/2017/03/Dataiku-Top-Prediction-Algorithms.jpg" width="800">

# %% [markdown]
# ### Árboles de regresión
#
# Los árboles de decisión son formas extremadamente intuitivas para clasificar o etiquetar objetos: simplemente hace una serie de preguntas diseñadas para concentrarse en la regresión o clasificación.
# Por ejemplo, si desea construir un árbol de decisión para clasificar una casa, puede construir el que se muestra aquí:
#
# <img src="https://raw.githubusercontent.com/RodrigoLaraMolina/DPATTSrc/master/decision-tree-house.png" alt="decision_tree" style="width: 700px;" align="center" frameborder="200"/>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Defino el RandomForest
rf = RandomForestRegressor(random_state=23)

# ajusto el modelos
rf.fit(X, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=23, verbose=0,
#                       warm_start=False)

# %%
metricas = ['RMSE: {:.3f}'.format(np.sqrt(metrics.mean_squared_error(valor_ref['V_REF'], rf.predict(X)))),
            'MAE: {:.3f}'.format(metrics.mean_absolute_error(valor_ref['V_REF'], rf.predict(X)))]

plt.figure(figsize = (12,8))
plt.scatter(valor_ref['V_REF'], rf.predict(X), s = 0.1, label = '\n'.join(metricas))
plt.plot([-0.2,5e6], [-0.2,5e6], color = 'black', linestyle = 'dotted')
plt.xlabel('Eventos reales')
plt.ylabel('Eventos predichos')
plt.legend(loc = 'lower right')
plt.title('Valores reales y predichos metro cuadrado Random Forest \n Manzanas de entrenamiento en Bogotá', fontsize=16);

# %%
### Ejercicio: Juegue con árboles y con GBM, y con los múltiples parámetros de los modelos.
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
